# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# Import your libraries:

# %matplotlib inline

import numpy as np
import pandas as pd

# %% [markdown]
# In this lab, we will explore a dataset that describes websites with different features and labels them either benign or malicious . We will use supervised learning algorithms to figure out what feature patterns malicious websites are likely to have and use our model to predict malicious websites.
#
# # Challenge 1 - Explore The Dataset
#
# Let's start by exploring the dataset. First load the data file:

# %%
websites = pd.read_csv('../website.csv')

# %% [markdown]
# #### Explore the data from an bird's-eye view.
#
# You should already been very familiar with the procedures now so we won't provide the instructions step by step. Reflect on what you did in the previous labs and explore the dataset.
#
# Things you'll be looking for:
#
# * What the dataset looks like?
# * What are the data types?
# * Which columns contain the features of the websites?
# * Which column contains the feature we will predict? What is the code standing for benign vs malicious websites?
# * Do we need to transform any of the columns from categorical to ordinal values? If so what are these columns?
#
# Feel free to add additional cells for your explorations. Make sure to comment what you find out.

# %%
# Your code here
websites.head()
# Out:
#        URL  URL_LENGTH  NUMBER_SPECIAL_CHARACTERS     CHARSET  \
# 0   M0_109          16                          7  iso-8859-1
# 1  B0_2314          16                          6       UTF-8
# 2   B0_911          16                          6    us-ascii
# 3   B0_113          17                          6  ISO-8859-1
# 4   B0_403          17                          6       UTF-8
#
#                   SERVER  CONTENT_LENGTH WHOIS_COUNTRY WHOIS_STATEPRO  \
# 0                  nginx           263.0          None           None
# 1          Apache/2.4.10         15087.0          None           None
# 2  Microsoft-HTTPAPI/2.0           324.0          None           None
# 3                  nginx           162.0            US             AK
# 4                   None        124140.0            US             TX
#
#       WHOIS_REGDATE WHOIS_UPDATED_DATE  ...  DIST_REMOTE_TCP_PORT  REMOTE_IPS  \
# 0  10/10/2015 18:21               None  ...                     0           2
# 1              None               None  ...                     7           4
# 2              None               None  ...                     0           0
# 3    7/10/1997 4:00    12/09/2013 0:45  ...                    22           3
# 4   12/05/1996 0:00    11/04/2017 0:00  ...                     2           5
#
#    APP_BYTES  SOURCE_APP_PACKETS  REMOTE_APP_PACKETS  SOURCE_APP_BYTES  \
# 0        700                   9                  10              1153
# 1       1230                  17                  19              1265
# 2          0                   0                   0                 0
# 3       3812                  39                  37             18784
# 4       4278                  61                  62            129889
#
#    REMOTE_APP_BYTES  APP_PACKETS  DNS_QUERY_TIMES  Type
# 0               832            9              2.0     1
# 1              1230           17              0.0     0
# 2                 0            0              0.0     0
# 3              4380           39              8.0     0
# 4              4586           61              4.0     0
#
# [5 rows x 21 columns]

# %%
websites.dtypes
# Out:
# URL                           object
# URL_LENGTH                     int64
# NUMBER_SPECIAL_CHARACTERS      int64
# CHARSET                       object
# SERVER                        object
# CONTENT_LENGTH               float64
# WHOIS_COUNTRY                 object
# WHOIS_STATEPRO                object
# WHOIS_REGDATE                 object
# WHOIS_UPDATED_DATE            object
# TCP_CONVERSATION_EXCHANGE      int64
# DIST_REMOTE_TCP_PORT           int64
# REMOTE_IPS                     int64
# APP_BYTES                      int64
# SOURCE_APP_PACKETS             int64
# REMOTE_APP_PACKETS             int64
# SOURCE_APP_BYTES               int64
# REMOTE_APP_BYTES               int64
# APP_PACKETS                    int64
# DNS_QUERY_TIMES              float64
# Type                           int64
# dtype: object

# %%
# Your comment here
websites['WHOIS_COUNTRY'].unique()
# Out:
# array(['None', 'US', 'SC', 'GB', 'UK', 'RU', 'AU', 'CA', 'PA', 'se', 'IN',
#        'LU', 'TH', "[u'GB'; u'UK']", 'FR', 'NL', 'UG', 'JP', 'CN', 'SE',
#        'SI', 'IL', 'ru', 'KY', 'AT', 'CZ', 'PH', 'BE', 'NO', 'TR', 'LV',
#        'DE', 'ES', 'BR', 'us', 'KR', 'HK', 'UA', 'CH', 'United Kingdom',
#        'BS', 'PK', 'IT', 'Cyprus', 'BY', 'AE', 'IE', 'UY', 'KG'],
#       dtype=object)

# %%
websites['Type'].unique()
# Out:
# array([1, 0])

# %%
websites['URL'].unique()
# Out:
# array(['M0_109', 'B0_2314', 'B0_911', ..., 'B0_162', 'B0_1152', 'B0_676'],
#       dtype=object)

# %%
sub = "M"
#websites["Malicious"]= websites["URL"].str.find(sub)
websites[websites['URL'].str.contains(sub)]
# Out:
#          URL  URL_LENGTH  NUMBER_SPECIAL_CHARACTERS     CHARSET  \
# 0     M0_109          16                          7  iso-8859-1
# 8      M2_17          20                          5       utf-8
# 9      M3_75          20                          5       utf-8
# 15     M0_71          21                          7  ISO-8859-1
# 16     M0_97          21                          7  iso-8859-1
# ...      ...         ...                        ...         ...
# 1772   M4_61         173                         34       UTF-8
# 1773   M4_39         178                         16       UTF-8
# 1775   M4_45         194                         17       UTF-8
# 1776   M4_48         194                         16       UTF-8
# 1777   M4_41         198                         17       UTF-8
#
#                                                  SERVER  CONTENT_LENGTH  \
# 0                                                 nginx           263.0
# 8                                          nginx/1.10.1             NaN
# 9                                          nginx/1.10.1             NaN
# 15    Apache/2.4.23 (Unix) OpenSSL/1.0.1e-fips mod_b...           957.0
# 16                                                nginx           686.0
# ...                                                 ...             ...
# 1772                                             Apache             NaN
# 1773                                             Apache             NaN
# 1775                                             Apache             NaN
# 1776                                             Apache             NaN
# 1777                                             Apache             NaN
#
#      WHOIS_COUNTRY       WHOIS_STATEPRO     WHOIS_REGDATE WHOIS_UPDATED_DATE  \
# 0             None                 None  10/10/2015 18:21               None
# 8             None                 None    8/11/2014 7:41               None
# 9             None                 None    8/11/2014 7:41               None
# 15              UK                 None   16/07/2000 0:00     4/07/2015 0:00
# 16              RU  Novosibirskaya obl.   25/05/2013 0:00    23/05/2016 0:00
# ...            ...                  ...               ...                ...
# 1772            ES            Barcelona   17/09/2008 0:00     2/09/2016 0:00
# 1773            ES            Barcelona   17/09/2008 0:00     2/09/2016 0:00
# 1775            ES            Barcelona   17/09/2008 0:00     2/09/2016 0:00
# 1776            ES            Barcelona   17/09/2008 0:00     2/09/2016 0:00
# 1777            ES            Barcelona   17/09/2008 0:00     2/09/2016 0:00
#
#       ...  DIST_REMOTE_TCP_PORT  REMOTE_IPS  APP_BYTES  SOURCE_APP_PACKETS  \
# 0     ...                     0           2        700                   9
# 8     ...                     0           0          0                   2
# 9     ...                     0           0          0                   2
# 15    ...                     0           1        717                  11
# 16    ...                     0           2        603                   8
# ...   ...                   ...         ...        ...                 ...
# 1772  ...                     1           1         90                   1
# 1773  ...                     0           0          0                   0
# 1775  ...                     0           0          0                   0
# 1776  ...                     0           0          0                   0
# 1777  ...                     0           0          0                   0
#
#       REMOTE_APP_PACKETS  SOURCE_APP_BYTES  REMOTE_APP_BYTES  APP_PACKETS  \
# 0                     10              1153               832            9
# 8                      3               213               146            2
# 9                      1                62               146            2
# 15                    10              1960              1011           11
# 16                     9              1580               745            8
# ...                  ...               ...               ...          ...
# 1772                   5               416                90            1
# 1773                   3               186                 0            0
# 1775                   3               186                 0            0
# 1776                   3               186                 0            0
# 1777                   2               124                 0            0
#
#       DNS_QUERY_TIMES  Type
# 0                 2.0     1
# 8                 2.0     1
# 9                 2.0     1
# 15                4.0     1
# 16                2.0     1
# ...               ...   ...
# 1772              0.0     1
# 1773              0.0     1
# 1775              0.0     1
# 1776              0.0     1
# 1777              0.0     1
#
# [216 rows x 21 columns]

# %%
websites
# Out:
#           URL  URL_LENGTH  NUMBER_SPECIAL_CHARACTERS     CHARSET  \
# 0      M0_109          16                          7  iso-8859-1
# 1     B0_2314          16                          6       UTF-8
# 2      B0_911          16                          6    us-ascii
# 3      B0_113          17                          6  ISO-8859-1
# 4      B0_403          17                          6       UTF-8
# ...       ...         ...                        ...         ...
# 1776    M4_48         194                         16       UTF-8
# 1777    M4_41         198                         17       UTF-8
# 1778   B0_162         201                         34       utf-8
# 1779  B0_1152         234                         34  ISO-8859-1
# 1780   B0_676         249                         40       utf-8
#
#                       SERVER  CONTENT_LENGTH WHOIS_COUNTRY WHOIS_STATEPRO  \
# 0                      nginx           263.0          None           None
# 1              Apache/2.4.10         15087.0          None           None
# 2      Microsoft-HTTPAPI/2.0           324.0          None           None
# 3                      nginx           162.0            US             AK
# 4                       None        124140.0            US             TX
# ...                      ...             ...           ...            ...
# 1776                  Apache             NaN            ES      Barcelona
# 1777                  Apache             NaN            ES      Barcelona
# 1778  Apache/2.2.16 (Debian)          8904.0            US             FL
# 1779        cloudflare-nginx             NaN            US             CA
# 1780       Microsoft-IIS/8.5         24435.0            US      Wisconsin
#
#          WHOIS_REGDATE WHOIS_UPDATED_DATE  ...  DIST_REMOTE_TCP_PORT  \
# 0     10/10/2015 18:21               None  ...                     0
# 1                 None               None  ...                     7
# 2                 None               None  ...                     0
# 3       7/10/1997 4:00    12/09/2013 0:45  ...                    22
# 4      12/05/1996 0:00    11/04/2017 0:00  ...                     2
# ...                ...                ...  ...                   ...
# 1776   17/09/2008 0:00     2/09/2016 0:00  ...                     0
# 1777   17/09/2008 0:00     2/09/2016 0:00  ...                     0
# 1778   15/02/1999 0:00    15/07/2015 0:00  ...                     2
# 1779    1/04/1998 0:00     9/12/2016 0:00  ...                     0
# 1780   14/11/2008 0:00    20/11/2013 0:00  ...                     6
#
#       REMOTE_IPS  APP_BYTES  SOURCE_APP_PACKETS  REMOTE_APP_PACKETS  \
# 0              2        700                   9                  10
# 1              4       1230                  17                  19
# 2              0          0                   0                   0
# 3              3       3812                  39                  37
# 4              5       4278                  61                  62
# ...          ...        ...                 ...                 ...
# 1776           0          0                   0                   3
# 1777           0          0                   0                   2
# 1778           6       6631                  87                  89
# 1779           0          0                   0                   0
# 1780          11       2314                  25                  28
#
#       SOURCE_APP_BYTES  REMOTE_APP_BYTES  APP_PACKETS  DNS_QUERY_TIMES  Type
# 0                 1153               832            9              2.0     1
# 1                 1265              1230           17              0.0     0
# 2                    0                 0            0              0.0     0
# 3                18784              4380           39              8.0     0
# 4               129889              4586           61              4.0     0
# ...                ...               ...          ...              ...   ...
# 1776               186                 0            0              0.0     1
# 1777               124                 0            0              0.0     1
# 1778            132181              6945           87              4.0     0
# 1779                 0                 0            0              0.0     0
# 1780              3039              2776           25              6.0     0
#
# [1781 rows x 21 columns]

# %%
websites.isna().sum()/len(websites['CONTENT_LENGTH'])
# Out:
# URL                          0.000000
# URL_LENGTH                   0.000000
# NUMBER_SPECIAL_CHARACTERS    0.000000
# CHARSET                      0.000000
# SERVER                       0.000561
# CONTENT_LENGTH               0.455924
# WHOIS_COUNTRY                0.000000
# WHOIS_STATEPRO               0.000000
# WHOIS_REGDATE                0.000000
# WHOIS_UPDATED_DATE           0.000000
# TCP_CONVERSATION_EXCHANGE    0.000000
# DIST_REMOTE_TCP_PORT         0.000000
# REMOTE_IPS                   0.000000
# APP_BYTES                    0.000000
# SOURCE_APP_PACKETS           0.000000
# REMOTE_APP_PACKETS           0.000000
# SOURCE_APP_BYTES             0.000000
# REMOTE_APP_BYTES             0.000000
# APP_PACKETS                  0.000000
# DNS_QUERY_TIMES              0.000561
# Type                         0.000000
# dtype: float64

# %%
websites = pd.get_dummies(websites, columns =['Type'])

# %%
websites
# Out:
#           URL  URL_LENGTH  NUMBER_SPECIAL_CHARACTERS     CHARSET  \
# 0      M0_109          16                          7  iso-8859-1
# 1     B0_2314          16                          6       UTF-8
# 2      B0_911          16                          6    us-ascii
# 3      B0_113          17                          6  ISO-8859-1
# 4      B0_403          17                          6       UTF-8
# ...       ...         ...                        ...         ...
# 1776    M4_48         194                         16       UTF-8
# 1777    M4_41         198                         17       UTF-8
# 1778   B0_162         201                         34       utf-8
# 1779  B0_1152         234                         34  ISO-8859-1
# 1780   B0_676         249                         40       utf-8
#
#                       SERVER  CONTENT_LENGTH WHOIS_COUNTRY WHOIS_STATEPRO  \
# 0                      nginx           263.0          None           None
# 1              Apache/2.4.10         15087.0          None           None
# 2      Microsoft-HTTPAPI/2.0           324.0          None           None
# 3                      nginx           162.0            US             AK
# 4                       None        124140.0            US             TX
# ...                      ...             ...           ...            ...
# 1776                  Apache             NaN            ES      Barcelona
# 1777                  Apache             NaN            ES      Barcelona
# 1778  Apache/2.2.16 (Debian)          8904.0            US             FL
# 1779        cloudflare-nginx             NaN            US             CA
# 1780       Microsoft-IIS/8.5         24435.0            US      Wisconsin
#
#          WHOIS_REGDATE WHOIS_UPDATED_DATE  ...  REMOTE_IPS  APP_BYTES  \
# 0     10/10/2015 18:21               None  ...           2        700
# 1                 None               None  ...           4       1230
# 2                 None               None  ...           0          0
# 3       7/10/1997 4:00    12/09/2013 0:45  ...           3       3812
# 4      12/05/1996 0:00    11/04/2017 0:00  ...           5       4278
# ...                ...                ...  ...         ...        ...
# 1776   17/09/2008 0:00     2/09/2016 0:00  ...           0          0
# 1777   17/09/2008 0:00     2/09/2016 0:00  ...           0          0
# 1778   15/02/1999 0:00    15/07/2015 0:00  ...           6       6631
# 1779    1/04/1998 0:00     9/12/2016 0:00  ...           0          0
# 1780   14/11/2008 0:00    20/11/2013 0:00  ...          11       2314
#
#       SOURCE_APP_PACKETS  REMOTE_APP_PACKETS  SOURCE_APP_BYTES  \
# 0                      9                  10              1153
# 1                     17                  19              1265
# 2                      0                   0                 0
# 3                     39                  37             18784
# 4                     61                  62            129889
# ...                  ...                 ...               ...
# 1776                   0                   3               186
# 1777                   0                   2               124
# 1778                  87                  89            132181
# 1779                   0                   0                 0
# 1780                  25                  28              3039
#
#       REMOTE_APP_BYTES  APP_PACKETS  DNS_QUERY_TIMES  Type_0  Type_1
# 0                  832            9              2.0       0       1
# 1                 1230           17              0.0       1       0
# 2                    0            0              0.0       1       0
# 3                 4380           39              8.0       1       0
# 4                 4586           61              4.0       1       0
# ...                ...          ...              ...     ...     ...
# 1776                 0            0              0.0       0       1
# 1777                 0            0              0.0       0       1
# 1778              6945           87              4.0       1       0
# 1779                 0            0              0.0       1       0
# 1780              2776           25              6.0       1       0
#
# [1781 rows x 22 columns]

# %%
# He transformado la columna Type a categórica porque tiene dos valores.

# %% [markdown]
# #### Next, evaluate if the columns in this dataset are strongly correlated.
#
# In the Mushroom supervised learning lab we did recently, we mentioned we are concerned if our dataset has strongly correlated columns because if it is the case we need to choose certain ML algorithms instead of others. We need to evaluate this for our dataset now.
#
# Luckily, most of the columns in this dataset are ordinal which makes things a lot easier for us. In the next cells below, evaluate the level of collinearity of the data.
#
# We provide some general directions for you to consult in order to complete this step:
#
# 1. You will create a correlation matrix using the numeric columns in the dataset.
#
# 1. Create a heatmap using `seaborn` to visualize which columns have high collinearity.
#
# 1. Comment on which columns you might need to remove due to high collinearity.

# %%
# Your code here
import matplotlib.pyplot as plt
import seaborn as sns

corr = websites.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow0_col1 {
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow0_col2 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow0_col4 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow0_col5 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow0_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow0_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow0_col9 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow0_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow0_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow0_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow0_col13 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow0_col14 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow1_col0 {
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow1_col2 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow1_col4 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow1_col5 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow1_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow1_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow1_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow1_col9 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow1_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow1_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow1_col12 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow1_col13 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow1_col14 {
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow2_col0 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow2_col1 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow2_col3 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow2_col4 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow2_col5 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow2_col6 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow2_col7 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow2_col8 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow2_col9 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow2_col10 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow2_col11 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow2_col12 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow2_col13 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow2_col14 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow3_col0 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow3_col1 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow3_col2 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow3_col4 {
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow3_col5 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow3_col6 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow3_col7 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow3_col8 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow3_col9 {
#             background-color:  #de614d;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow3_col10 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow3_col11 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow3_col12 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow3_col13 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_036e35f8_18d9_11ea_a8e3_e913263e0b8crow3_col14 {
#             background-color:  #d7dce3;

# %%
#upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(np.bool))

# %%
#to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#to_drop
websites
# Out:
#           URL  URL_LENGTH  NUMBER_SPECIAL_CHARACTERS     CHARSET  \
# 0      M0_109          16                          7  iso-8859-1
# 1     B0_2314          16                          6       UTF-8
# 2      B0_911          16                          6    us-ascii
# 3      B0_113          17                          6  ISO-8859-1
# 4      B0_403          17                          6       UTF-8
# ...       ...         ...                        ...         ...
# 1776    M4_48         194                         16       UTF-8
# 1777    M4_41         198                         17       UTF-8
# 1778   B0_162         201                         34       utf-8
# 1779  B0_1152         234                         34  ISO-8859-1
# 1780   B0_676         249                         40       utf-8
#
#                       SERVER  CONTENT_LENGTH WHOIS_COUNTRY WHOIS_STATEPRO  \
# 0                      nginx           263.0          None           None
# 1              Apache/2.4.10         15087.0          None           None
# 2      Microsoft-HTTPAPI/2.0           324.0          None           None
# 3                      nginx           162.0            US             AK
# 4                       None        124140.0            US             TX
# ...                      ...             ...           ...            ...
# 1776                  Apache             NaN            ES      Barcelona
# 1777                  Apache             NaN            ES      Barcelona
# 1778  Apache/2.2.16 (Debian)          8904.0            US             FL
# 1779        cloudflare-nginx             NaN            US             CA
# 1780       Microsoft-IIS/8.5         24435.0            US      Wisconsin
#
#          WHOIS_REGDATE WHOIS_UPDATED_DATE  ...  REMOTE_IPS  APP_BYTES  \
# 0     10/10/2015 18:21               None  ...           2        700
# 1                 None               None  ...           4       1230
# 2                 None               None  ...           0          0
# 3       7/10/1997 4:00    12/09/2013 0:45  ...           3       3812
# 4      12/05/1996 0:00    11/04/2017 0:00  ...           5       4278
# ...                ...                ...  ...         ...        ...
# 1776   17/09/2008 0:00     2/09/2016 0:00  ...           0          0
# 1777   17/09/2008 0:00     2/09/2016 0:00  ...           0          0
# 1778   15/02/1999 0:00    15/07/2015 0:00  ...           6       6631
# 1779    1/04/1998 0:00     9/12/2016 0:00  ...           0          0
# 1780   14/11/2008 0:00    20/11/2013 0:00  ...          11       2314
#
#       SOURCE_APP_PACKETS  REMOTE_APP_PACKETS  SOURCE_APP_BYTES  \
# 0                      9                  10              1153
# 1                     17                  19              1265
# 2                      0                   0                 0
# 3                     39                  37             18784
# 4                     61                  62            129889
# ...                  ...                 ...               ...
# 1776                   0                   3               186
# 1777                   0                   2               124
# 1778                  87                  89            132181
# 1779                   0                   0                 0
# 1780                  25                  28              3039
#
#       REMOTE_APP_BYTES  APP_PACKETS  DNS_QUERY_TIMES  Type_0  Type_1
# 0                  832            9              2.0       0       1
# 1                 1230           17              0.0       1       0
# 2                    0            0              0.0       1       0
# 3                 4380           39              8.0       1       0
# 4                 4586           61              4.0       1       0
# ...                ...          ...              ...     ...     ...
# 1776                 0            0              0.0       0       1
# 1777                 0            0              0.0       0       1
# 1778              6945           87              4.0       1       0
# 1779                 0            0              0.0       1       0
# 1780              2776           25              6.0       1       0
#
# [1781 rows x 22 columns]

# %%
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
# Your comment here
# Las features que tienen mayor correlación, al no ser discriminativas, pueden eliminarse

# %% [markdown]
# # Challenge 2 - Remove Column Collinearity.
#
# From the heatmap you created, you should have seen at least 3 columns that can be removed due to high collinearity. Remove these columns from the dataset.
#
# Note that you should remove as few columns as you can. You don't have to remove all the columns at once. But instead, try removing one column, then produce the heatmap again to determine if additional columns should be removed. As long as the dataset no longer contains columns that are correlated for over 90%, you can stop. Also, keep in mind when two columns have high collinearity, you only need to remove one of them but not both.
#
# In the cells below, remove as few columns as you can to eliminate the high collinearity in the dataset. Make sure to comment on your way so that the instructional team can learn about your thinking process which allows them to give feedback. At the end, print the heatmap again.

# %%
# Your code here

websites = websites.drop(columns=['SOURCE_APP_PACKETS','REMOTE_APP_PACKETS','REMOTE_APP_BYTES'], axis=1)

# %%
# Your comment here
# He eliminado aquellas columnas que presentaban una correlación alta en el matriz de correlaciones porque no son discriminativas

# %%
# Print heatmap again
corr = websites.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow0_col1 {
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow0_col2 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow0_col4 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow0_col5 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow0_col7 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow0_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow0_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow0_col10 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow0_col11 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow1_col0 {
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow1_col2 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow1_col4 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow1_col5 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow1_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow1_col7 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow1_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow1_col9 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow1_col10 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow1_col11 {
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow2_col0 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow2_col1 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow2_col3 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow2_col4 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow2_col5 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow2_col6 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow2_col7 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow2_col8 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow2_col9 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow2_col10 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow2_col11 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow3_col0 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow3_col1 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow3_col2 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow3_col4 {
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow3_col5 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow3_col6 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow3_col7 {
#             background-color:  #de614d;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow3_col8 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow3_col9 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow3_col10 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow3_col11 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow4_col0 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow4_col1 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow4_col2 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow4_col3 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow4_col5 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow4_col6 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow4_col7 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow4_col8 {
#             background-color:  #eed0c0;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow4_col9 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow4_col10 {
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }    #T_049dce2a_18d9_11ea_a8e3_e913263e0b8crow4_col11 {
#             background-color:  #d2dbe8;
#             color:  #0

# %% [markdown]
# # Challenge 3 - Handle Missing Values
#
# The next step would be handling missing values. **We start by examining the number of missing values in each column, which you will do in the next cell.**

# %%
# Your code here
websites.isna().sum()
# Out:
# URL                            0
# URL_LENGTH                     0
# NUMBER_SPECIAL_CHARACTERS      0
# CHARSET                        0
# SERVER                         1
# CONTENT_LENGTH               812
# WHOIS_COUNTRY                  0
# WHOIS_STATEPRO                 0
# WHOIS_REGDATE                  0
# WHOIS_UPDATED_DATE             0
# TCP_CONVERSATION_EXCHANGE      0
# DIST_REMOTE_TCP_PORT           0
# REMOTE_IPS                     0
# APP_BYTES                      0
# SOURCE_APP_BYTES               0
# APP_PACKETS                    0
# DNS_QUERY_TIMES                1
# Type_0                         0
# Type_1                         0
# dtype: int64

# %% [markdown]
# If you remember in the previous labs, we drop a column if the column contains a high proportion of missing values. After dropping those problematic columns, we drop the rows with missing values.
#
# #### In the cells below, handle the missing values from the dataset. Remember to comment the rationale of your decisions.

# %%
# Your code here
websites.dropna(subset = ['CONTENT_LENGTH'],inplace=True)

# %%
# Your comment here
# He eliminado la columna que tiene ayor número de missing values

# %% [markdown]
# #### Again, examine the number of missing values in each column.
#
# If all cleaned, proceed. Otherwise, go back and do more cleaning.

# %%
# Examine missing values in each column
websites.isna().sum()
# Out:
# URL                          0
# URL_LENGTH                   0
# NUMBER_SPECIAL_CHARACTERS    0
# CHARSET                      0
# SERVER                       1
# CONTENT_LENGTH               0
# WHOIS_COUNTRY                0
# WHOIS_STATEPRO               0
# WHOIS_REGDATE                0
# WHOIS_UPDATED_DATE           0
# TCP_CONVERSATION_EXCHANGE    0
# DIST_REMOTE_TCP_PORT         0
# REMOTE_IPS                   0
# APP_BYTES                    0
# SOURCE_APP_BYTES             0
# APP_PACKETS                  0
# DNS_QUERY_TIMES              1
# Type_0                       0
# Type_1                       0
# dtype: int64

# %% [markdown]
# # Challenge 4 - Handle `WHOIS_*` Categorical Data

# %% [markdown]
# There are several categorical columns we need to handle. These columns are:
#
# * `URL`
# * `CHARSET`
# * `SERVER`
# * `WHOIS_COUNTRY`
# * `WHOIS_STATEPRO`
# * `WHOIS_REGDATE`
# * `WHOIS_UPDATED_DATE`
#
# How to handle string columns is always case by case. Let's start by working on `WHOIS_COUNTRY`. Your steps are:
#
# 1. List out the unique values of `WHOIS_COUNTRY`.
# 1. Consolidate the country values with consistent country codes. For example, the following values refer to the same country and should use consistent country code:
#     * `CY` and `Cyprus`
#     * `US` and `us`
#     * `SE` and `se`
#     * `GB`, `United Kingdom`, and `[u'GB'; u'UK']`
#
# #### In the cells below, fix the country values as intructed above.

# %%
# Your code here
websites['WHOIS_COUNTRY'].unique()
# Out:
# array(['None', 'US', 'GB', 'UK', 'RU', 'AU', 'CA', 'PA', 'se', 'IN',
#        "[u'GB'; u'UK']", 'UG', 'JP', 'SI', 'IL', 'AT', 'CN', 'BE', 'NO',
#        'TR', 'KY', 'BR', 'SC', 'NL', 'FR', 'CZ', 'KR', 'UA', 'CH', 'HK',
#        'United Kingdom', 'DE', 'IT', 'BS', 'SE', 'Cyprus', 'us', 'BY',
#        'AE', 'IE', 'PH', 'UY'], dtype=object)

# %%
websites['WHOIS_COUNTRY'].replace(to_replace =["United Kingdom", "[u'GB'; u'UK']"],  
                            value ="GB",inplace=True)

# %%
websites['WHOIS_COUNTRY'].unique()
# Out:
# array(['None', 'US', 'GB', 'UK', 'RU', 'AU', 'CA', 'PA', 'se', 'IN', 'UG',
#        'JP', 'SI', 'IL', 'AT', 'CN', 'BE', 'NO', 'TR', 'KY', 'BR', 'SC',
#        'NL', 'FR', 'CZ', 'KR', 'UA', 'CH', 'HK', 'DE', 'IT', 'BS', 'SE',
#        'Cyprus', 'us', 'BY', 'AE', 'IE', 'PH', 'UY'], dtype=object)

# %%
websites['WHOIS_COUNTRY'].replace("se",
           "SE", inplace=True)

# %%
websites['WHOIS_COUNTRY'].replace("Cyprus",
           "CY", inplace=True)

# %%
websites['WHOIS_COUNTRY'].replace("us",
           "US", inplace=True)

# %%
websites['WHOIS_COUNTRY'].unique()
# Out:
# array(['None', 'US', 'GB', 'UK', 'RU', 'AU', 'CA', 'PA', 'SE', 'IN', 'UG',
#        'JP', 'SI', 'IL', 'AT', 'CN', 'BE', 'NO', 'TR', 'KY', 'BR', 'SC',
#        'NL', 'FR', 'CZ', 'KR', 'UA', 'CH', 'HK', 'DE', 'IT', 'BS', 'CY',
#        'BY', 'AE', 'IE', 'PH', 'UY'], dtype=object)

# %% [markdown]
# Since we have fixed the country values, can we convert this column to ordinal now?
#
# Not yet. If you reflect on the previous labs how we handle categorical columns, you probably remember we ended up dropping a lot of those columns because there are too many unique values. Too many unique values in a column is not desirable in machine learning because it makes prediction inaccurate. But there are workarounds under certain conditions. One of the fixable conditions is:
#
# #### If a limited number of values account for the majority of data, we can retain these top values and re-label all other rare values.
#
# The `WHOIS_COUNTRY` column happens to be this case. You can verify it by print a bar chart of the `value_counts` in the next cell to verify:

# %%
# Your code here
websites['WHOIS_COUNTRY'].value_counts()[:10]
# Out:
# US      592
# None    208
# CA       46
# GB       21
# AU       16
# PA       10
# CH        6
# JP        6
# UK        6
# IN        6
# Name: WHOIS_COUNTRY, dtype: int64

# %% [markdown]
# #### After verifying, now let's keep the top 10 values of the column and re-label other columns with `OTHER`.

# %%
# Your code here
def others(x):
    if x not in websites["WHOIS_COUNTRY"].value_counts()[:10].index:
        return "OTHER"
    else:
        return x




websites["WHOIS_COUNTRY"] = websites["WHOIS_COUNTRY"].apply(others)

# %%
websites['WHOIS_COUNTRY'].value_counts()
# Out:
# US       592
# None     208
# OTHER     52
# CA        46
# GB        21
# AU        16
# PA        10
# CH         6
# IN         6
# JP         6
# UK         6
# Name: WHOIS_COUNTRY, dtype: int64

# %%
websites['WHOIS_COUNTRY'].unique()
# Out:
# array(['None', 'US', 'GB', 'UK', 'OTHER', 'AU', 'CA', 'PA', 'IN', 'JP',
#        'CH'], dtype=object)

# %% [markdown]
# Now since `WHOIS_COUNTRY` has been re-labelled, we don't need `WHOIS_STATEPRO` any more because the values of the states or provinces may not be relevant any more. We'll drop this column.
#
# In addition, we will also drop `WHOIS_REGDATE` and `WHOIS_UPDATED_DATE`. These are the registration and update dates of the website domains. Not of our concerns.
#
# #### In the next cell, drop `['WHOIS_STATEPRO', 'WHOIS_REGDATE', 'WHOIS_UPDATED_DATE']`.

# %%
# Your code here
to_drop = ['WHOIS_STATEPRO', 'WHOIS_REGDATE', 'WHOIS_UPDATED_DATE']
websites.drop(to_drop, axis=1, inplace = True)

# %% [markdown]
# # Challenge 5 - Handle Remaining Categorical Data & Convert to Ordinal
#
# Now print the `dtypes` of the data again. Besides `WHOIS_COUNTRY` which we already fixed, there should be 3 categorical columns left: `URL`, `CHARSET`, and `SERVER`.

# %%
# Your code here
websites.dtypes
# Out:
# URL                           object
# URL_LENGTH                     int64
# NUMBER_SPECIAL_CHARACTERS      int64
# CHARSET                       object
# SERVER                        object
# CONTENT_LENGTH               float64
# WHOIS_COUNTRY                 object
# TCP_CONVERSATION_EXCHANGE      int64
# DIST_REMOTE_TCP_PORT           int64
# REMOTE_IPS                     int64
# APP_BYTES                      int64
# SOURCE_APP_BYTES               int64
# APP_PACKETS                    int64
# DNS_QUERY_TIMES              float64
# Type_0                         uint8
# Type_1                         uint8
# dtype: object

# %% [markdown]
# #### `URL` is easy. We'll simply drop it because it has too many unique values that there's no way for us to consolidate.

# %%
# Your code here
websites.drop(['URL'], axis=1, inplace = True)

# %% [markdown]
# #### Print the unique value counts of `CHARSET`. You see there are only a few unique values. So we can keep it as it is.

# %%
# Your code here
websites['CHARSET'].unique()
# Out:
# array(['iso-8859-1', 'UTF-8', 'us-ascii', 'ISO-8859-1', 'utf-8', 'None',
#        'windows-1251', 'ISO-8859'], dtype=object)

# %% [markdown]
# `SERVER` is a little more complicated. Print its unique values and think about how you can consolidate those values.
#
# #### Before you think of your own solution, don't read the instructions that come next.

# %%
# Your code here

websites['SERVER'].unique()
# Out:
# array(['nginx', 'Apache/2.4.10', 'Microsoft-HTTPAPI/2.0', 'None',
#        'Apache/2', 'Apache/2.2.15 (Red Hat)',
#        'Apache/2.4.23 (Unix) OpenSSL/1.0.1e-fips mod_bwlimited/1.4',
#        'Apache/2.2.22', 'Apache/2.4.7 (Ubuntu)', 'Apache',
#        'Apache/2.4.12 (Unix) OpenSSL/1.0.1e-fips mod_bwlimited/1.4',
#        'Oracle-iPlanet-Web-Server/7.0', 'nginx/1.6.2', 'Heptu web server',
#        'Microsoft-IIS/7.5', 'nginx/1.12.0',
#        'Apache/2.4.25 (cPanel) OpenSSL/1.0.1e-fips mod_bwlimited/1.4',
#        'tsa_c', 'Apache/2.2.22 (Debian)', 'Apache/2.4.25',
#        'Apache/2.4.25 (Amazon) PHP/7.0.14', 'GSE',
#        'Apache/2.4.23 (Unix) OpenSSL/0.9.8e-fips-rhel5 mod_bwlimited/1.4',
#        'Apache/2.4.25 (Amazon) OpenSSL/1.0.1k-fips',
#        'Apache/2.2.22 (Ubuntu)',
#        'Apache/2.4.18 (Unix) OpenSSL/0.9.8e-fips-rhel5 mod_bwlimited/1.4',
#        'Apache/2.4.6 (CentOS) PHP/5.6.8', 'AmazonS3', 'ATS',
#        'Apache/2.2.27 (CentOS)', 'CherryPy/3.6.0',
#        'Apache/2.2.15 (CentOS)', 'KHL',
#        'Apache/2.4.6 (CentOS) OpenSSL/1.0.1e-fips mod_fcgid/2.3.9 PHP/5.4.16 mod_jk/1.2.40',
#        'Apache/2.2.3 (CentOS)', 'Apache/2.4', 'Apache/2.2.31 (Amazon)',
#        'Apache/2.4.10 (Debian)', 'Apache/2.4.12 (Ubuntu)',
#        'Apache/2.2.29 (Unix) mod_ssl/2.2.29 OpenSSL/1.0.1e-fips mod_bwlimited/1.4',
#        'mw2232.codfw.wmnet', 'Sucuri/Cloudproxy', 'Apache/2.4.23 (Unix)',
#        'cloudflare-nginx', 'Apache/2.0.52 (Red Hat)',
#        'Apache/1.3.31 (Unix) PHP/4.3.9 mod_perl/1.29 rus/PL30.20',
#        'Apache/2.2.13 (Unix) mod_ssl/2.2.13 OpenSSL/0.9.8e-fips-rhel5 mod_auth_passthrough/2.1 mod_bwlimited/1.4 PHP/5.2.10',
#        'ATS/5.3.0', 'Apache/2.2.3 (Red Hat)', 'nginx/1.4.3',
#        'Apache/2.2.29 (Unix) mod_ssl/2.2.29 OpenSSL/1.0.1e-fips mod_bwlimited/1.4 PHP/5.4.35',
#        'Apache/2.2.14 (FreeBSD) mod_ssl/2.2.14 OpenSSL/0.9.8y DAV/2 PHP/5.2.12 with Suhosin-Patch',
#        'nginx/1.8.0',
#        'Apache/2.2.14 (Unix) mod_ssl/2.2.14 OpenSSL/0.9.8e-fips-rhel5',
#        'Microsoft-IIS/8.0', 'Apache/2.4.18 (Ubuntu)',
#        'Apache/2.4.6 (CentOS) OpenSSL/1.0.1e-fips PHP/5.4.16 mod_apreq2-20090110/2.8.0 mod_perl/2.0.10 Perl/v5.24.1',
#        'Apache/2.2.20 (Unix)', 'nginx/1.11.10', 'Yippee-Ki-Yay',
#        'mw2165.codfw.wmnet', 'Apache/2.2.23 (Amazon)', 'LiteSpeed',
#        'Proxy Pandeiro UOL', 'openresty/1.11.2.2', 'Apache-Coyote/1.1',
#        'mw2225.codfw.wmnet', 'nginx/1.1.19', 'Varnish',
#        'Microsoft-IIS/8.5', 'Apache/2.4.6 (CentOS)', 'barista/5.1.3',
#        'nginx/1.11.2', 'Apache/2.4.25 (Debian)', 'ECD (fll/0790)',
#        'nginx/1.10.3',
#        'Apache/2.4.25 (FreeBSD) OpenSSL/1.0.1s-freebsd PHP/5.6.30',
#        'mw2239.codfw.wmnet', 'mw2255.codfw.wmnet',
#        'Apache/2.2.31 (Unix) mod_ssl/2.2.31 OpenSSL/1.0.1e-fips mod_bwlimited/1.4 mod_fcgid/2.3.9',
#        'nginx/1.13.0',
#        'Apache/2.2.31 (Unix) mod_ssl/2.2.31 OpenSSL/0.9.8e-fips-rhel5 mod_bwlimited/1.4',
#        'Apache/2.4.6 (CentOS) OpenSSL/1.0.1e-fips PHP/5.4.16',
#        'nginx/1.11.3', 'lighttpd', 'mw2230.codfw.wmnet',
#        'Apache/2.4.6 (CentOS) OpenSSL/1.0.1e-fips', 'AkamaiGHost',
#        'PWS/8.2.0.7', 'nginx/1.2.1',
#        'Apache/2.2.16 (Unix) mod_ssl/2.2.16 OpenSSL/0.9.8e-fips-rhel5 mod_auth_passthrough/2.1 mod_bwlimited/1.4',
#        'Play', 'Apache/2.2.11 (Unix) PHP/5.2.6', 'Scratch Web Server',
#        'nginx/1.4.6 (Ubuntu)', 'marrakesh 1.12.2', 'nginx/0.8.35',
#        'squid/3.3.8', 'nginx/1.8.1', 'Nginx (OpenBSD)',
#        'Zope/(2.13.16; python 2.6.8; linux2) ZServer/1.1',
#        'Apache/2.2.26 (Unix) mod_ssl/2.2.26 OpenSSL/0.9.8e-fips-rhel5 mod_bwlimited/1.4 PHP/5.4.26',
#        'Apache/2.2.21 (Unix) mod_ssl/2.2.21 OpenSSL/0.9.8e-fips-rhel5 PHP/5.3.10',
#        'Apache/2.2.27 (Unix) OpenAM Web Agent/4.0.1-1 mod_ssl/2.2.27 OpenSSL/1.0.1p PHP/5.3.28',
#        'Apache/2.2.32',
#        'Apache/2.4.6 (Unix) mod_jk/1.2.37 PHP/5.5.1 OpenSSL/1.0.1g mod_fcgid/2.3.9',
#        'mw2106.codfw.wmnet', 'Microsoft-IIS/7.0',
#        'Aeria Games & Entertainment',
#        'Apache/2.4.10 (Debian) PHP/5.6.30-0+deb8u1 mod_perl/2.0.9dev Perl/v5.20.2',
#        'mw2173.codfw.wmnet',
#        'Apache/2.4.6 (Red Hat Enterprise Linux) OpenSSL/1.0.1e-fips mod_fcgid/2.3.9 Communique/4.2.0',
#        'Apache/2.2.15 (CentOS) DAV/2 mod_ssl/2.2.15 OpenSSL/1.0.1e-fips PHP/5.3.3',
#        'Apache/2.4.6 (CentOS) OpenSSL/1.0.1e-fips PHP/7.0.14', 'Server',
#        'Apache/2.4.6 (Unix) mod_jk/1.2.37', 'Cowboy',
#        'Apache/2.2.14 (Unix) mod_ssl/2.2.14 OpenSSL/0.9.8a',
#        'Apache/2.4.10 (Ubuntu)', 'mw2257.codfw.wmnet', 'DMS/1.0.42',
#        'Application-Server', nan, 'mw2177.codfw.wmnet', 'lighttpd/1.4.28',
#        'mw2197.codfw.wmnet',
#        'Apache/2.2.31 (FreeBSD) PHP/5.4.15 mod_ssl/2.2.31 OpenSSL/1.0.2d DAV/2',
#        'Apache/2.2.26 (Unix) mod_ssl/2.2.26 OpenSSL/1.0.1e-fips DAV/2 mod_bwlimited/1.4',
#        '294', 'Microsoft-IIS/6.0', 'www.lexisnexis.com  9999',
#        'nginx/0.8.38', 'mw2238.codfw.wmnet', 'XXXXXXXXXXXXXXXXXXXXXX',
#        'Pizza/pepperoni', 'MI', 'Roxen/5.4.98-r2', 'nginx/1.10.1',
#        'mw2180.codfw.wmnet', 'nginx/1.9.13', 'nginx/1.7.12',
#        'Apache/2.0.63 (Unix) mod_ssl/2.0.63 OpenSSL/0.9.8e-fips-rhel5 mod_auth_passthrough/2.1 mod_bwlimited/1.4 PHP/5.3.6',
#        'Boston.com Frontend', 'My Arse',
#        'Apache/2.4.17 (Unix) OpenSSL/1.0.1e-fips PHP/5.6.19',
#        'Microsoft-IIS/7.5; litigation_essentials.lexisnexis.com  9999',
#        'Apache/2.2.16 (Debian)'], dtype=object)

# %% [markdown]
# ![Think Hard](../think-hard.jpg)

# %%
# Your comment here

# %% [markdown]
# Although there are so many unique values in the `SERVER` column, there are actually only 3 main server types: `Microsoft`, `Apache`, and `nginx`. Just check if each `SERVER` value contains any of those server types and re-label them. For `SERVER` values that don't contain any of those substrings, label with `Other`.
#
# At the end, your `SERVER` column should only contain 4 unique values: `Microsoft`, `Apache`, `nginx`, and `Other`.

# %%
# Your code here

# %%
# Count `SERVER` value counts here

# %% [markdown]
# OK, all our categorical data are fixed now. **Let's convert them to ordinal data using Pandas' `get_dummies` function ([documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html)).** Make sure you drop the categorical columns by passing `drop_first=True` to `get_dummies` as we don't need them any more. **Also, assign the data with dummy values to a new variable `website_dummy`.**

# %%
# Your code here

# %% [markdown]
# Now, inspect `website_dummy` to make sure the data and types are intended - there shouldn't be any categorical columns at this point.

# %%
# Your code here

# %% [markdown]
# # Challenge 6 - Modeling, Prediction, and Evaluation
#
# We'll start off this section by splitting the data to train and test. **Name your 4 variables `X_train`, `X_test`, `y_train`, and `y_test`. Select 80% of the data for training and 20% for testing.**

# %%
from sklearn.model_selection import train_test_split

# Your code here:

# %% [markdown]
# #### In this lab, we will try two different models and compare our results.
#
# The first model we will use in this lab is logistic regression. We have previously learned about logistic regression as a classification algorithm. In the cell below, load `LogisticRegression` from scikit-learn and initialize the model.

# %%
# Your code here:

# %% [markdown]
# Next, fit the model to our training data. We have already separated our data into 4 parts. Use those in your model.

# %%
# Your code here:

# %% [markdown]
# finally, import `confusion_matrix` and `accuracy_score` from `sklearn.metrics` and fit our testing data. Assign the fitted data to `y_pred` and print the confusion matrix as well as the accuracy score

# %%
# Your code here:

# %% [markdown]
# What are your thoughts on the performance of the model? Write your conclusions below.

# %%
# Your conclusions here:

# %% [markdown]
# #### Our second algorithm is is K-Nearest Neighbors.
#
# Though is it not required, we will fit a model using the training data and then test the performance of the model using the testing data. Start by loading `KNeighborsClassifier` from scikit-learn and then initializing and fitting the model. We'll start off with a model where k=3.

# %%
# Your code here:

# %% [markdown]
# To test your model, compute the predicted values for the testing sample and print the confusion matrix as well as the accuracy score.

# %%
# Your code here:

# %% [markdown]
# #### We'll create another K-Nearest Neighbors model with k=5.
#
# Initialize and fit the model below and print the confusion matrix and the accuracy score.

# %%
# Your code here:

# %% [markdown]
# Did you see an improvement in the confusion matrix when increasing k to 5? Did you see an improvement in the accuracy score? Write your conclusions below.

# %%
# Your conclusions here:

# %% [markdown]
# # Bonus Challenge - Feature Scaling
#
# Problem-solving in machine learning is iterative. You can improve your model prediction with various techniques (there is a sweetspot for the time you spend and the improvement you receive though). Now you've completed only one iteration of ML analysis. There are more iterations you can conduct to make improvements. In order to be able to do that, you will need deeper knowledge in statistics and master more data analysis techniques. In this bootcamp, we don't have time to achieve that advanced goal. But you will make constant efforts after the bootcamp to eventually get there.
#
# However, now we do want you to learn one of the advanced techniques which is called *feature scaling*. The idea of feature scaling is to standardize/normalize the range of independent variables or features of the data. This can make the outliers more apparent so that you can remove them. This step needs to happen during Challenge 6 after you split the training and test data because you don't want to split the data again which makes it impossible to compare your results with and without feature scaling. For general concepts about feature scaling, click [here](https://en.wikipedia.org/wiki/Feature_scaling). To read deeper, click [here](https://medium.com/greyatom/why-how-and-when-to-scale-your-features-4b30ab09db5e).
#
# In the next cell, attempt to improve your model prediction accuracy by means of feature scaling. A library you can utilize is `sklearn.preprocessing.RobustScaler` ([documentation](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.RobustScaler.html)). You'll use the `RobustScaler` to fit and transform your `X_train`, then transform `X_test`. You will use logistic regression to fit and predict your transformed data and obtain the accuracy score in the same way. Compare the accuracy score with your normalized data with the previous accuracy data. Is there an improvement?

# %%
# Your code here
